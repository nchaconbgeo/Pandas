# %% [markdown]
# Calculate percentiles

# %%
import pandas as pd
data=pd.read_csv("/Users/natalychacon/Documents/Ejercico_de_datos_Python/data.csv",skipinitialspace=True)

columns = list(data)
n=1
def percentile(x,dframe):
    percentile3 = percentileofscore(dframe, x,'weak') 
    return percentile3

for i in columns[0:-1]:
    jota = data[i].apply(percentile,args=[data[i]])
    data.insert(n,"percentile",jota,True)
    n=n+2
data
data.to_csv(r"/Users/natalychacon/Documents/Ejercico_de_datos_Python/data_perc.csv")
# Out:
#       word_freq_make  percentile  word_freq_address  percentile  \
# 0               0.00   77.113671               0.64   94.740274
# 1               0.21   85.546620               0.28   88.002608
# 2               0.06   78.548142               0.00   80.482504
# 3               0.00   77.113671               0.00   80.482504
# 4               0.00   77.113671               0.00   80.482504
# ...              ...         ...                ...         ...
# 4596            0.31   88.219952               0.00   80.482504
# 4597            0.00   77.113671               0.00   80.482504
# 4598            0.30   87.937405               0.00   80.482504
# 4599            0.96   97.696153               0.00   80.482504
# 4600            0.00   77.113671               0.00   80.482504
#
#       word_freq_all  percentile  word_freq_3d  percentile  word_freq_our  \
# 0              0.64   83.916540           0.0   98.978483           0.32
# ...
